# %%
import fitz  # PyMuPDF
import json
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

def extract_text_from_pdf(file_path):
    # Abre el archivo PDF
    doc = fitz.open(file_path)
    text = ""
    for page in doc:
        text += page.get_text()
    return text

def preprocess_data(text):
    # Dividir el texto en líneas y limpiar los datos
    lines = text.split('\n')
    lines = [line.strip() for line in lines if line.strip() != '']
    return lines

def feature_extraction(data):
    # Convertir datos a vectores para el análisis de clustering
    vectorizer = TfidfVectorizer(stop_words='english')
    X = vectorizer.fit_transform(data)
    return X, vectorizer

def cluster_data(X, n_clusters=10):
    # Aplicar K-means para agrupar líneas similares
    kmeans = KMeans(n_clusters=n_clusters)
    kmeans.fit(X)
    return kmeans.labels_

def organize_data(lines, labels):
    # Organizar los datos etiquetados en un diccionario
    grouped_data = {}
    for label, line in zip(labels, lines):
        if label in grouped_data:
            grouped_data[label].append(line)
        else:
            grouped_data[label] = [line]
    return grouped_data

def create_json_format(grouped_data):
    # Convertir los datos agrupados en un formato JSON específico
    json_data = {
       "nombre_cliente": r"Titular del contrato: (\w+ [\w ]+)",
        "dni_cliente": r"NIF: (\w+)",
        "calle_cliente": r"Dirección de suministro: ([\w ,]+)",
        "cp_cliente": r"(\d{5})",
        "población_cliente": r"Dirección suministro: .+ (\d{5}) (\w+)",
        "provincia_cliente": r"provincia_cliente: (\w+)",
        "nombre_comercializadora": r"nombre_comercializadora: (\w+)",
        "cif_comercializadora": r"CIF (\w+)",
        "dirección_comercializadora": r"Domicilio Social: ([\w ,]+)",
        "cp_comercializadora": r"Domicilio Social: .+?(\d{5})",
        "población_comercializadora": r"Domicilio Social: .+? \d{5} (\w+)",
        "provincia_comercializadora": r"provincia_comercializadora: (\w+)",
        "número_factura": r"Nº factura: (\w+)",
        "inicio_periodo": r"Periodo de Facturación: del (\d{2}/\d{2}/\d{4})",
        "fin_periodo": r"a (\d{2}/\d{2}/\d{4})",
        "importe_factura": r"TOTAL IMPORTE FACTURA(\d+,\d{2}) €",
        "fecha_cargo": r"Fecha de cargo: (\d{2} de \w+ de \d{4})",
        "consumo_periodo": r"Consumo\n(\d+ kWh)",
        "potencia_contratada": r"Potencia contratada: (\d,\d{3}) kW"
    }
    return json.dumps(json_data, indent=4)

# Uso del código
pdf_text = extract_text_from_pdf("./training/factura_0.pdf") #CAMBIA LA RUTA Y EL NOMBRE DE ARCHIVO
processed_text = preprocess_data(pdf_text)
X, vectorizer = feature_extraction(processed_text)
labels = cluster_data(X)
grouped_data = organize_data(processed_text, labels)
json_output = create_json_format(grouped_data)

print(json_output)
# Out:
# C:\Users\AdmInfo\AppData\Roaming\Python\Python311\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# {
#     "nombre_cliente": "Titular del contrato: (\\w+ [\\w ]+)",
#     "dni_cliente": "NIF: (\\w+)",
#     "calle_cliente": "Direcci\u00f3n de suministro: ([\\w ,]+)",
#     "cp_cliente": "(\\d{5})",
#     "poblaci\u00f3n_cliente": "Direcci\u00f3n suministro: .+ (\\d{5}) (\\w+)",
#     "provincia_cliente": "provincia_cliente: (\\w+)",
#     "nombre_comercializadora": "nombre_comercializadora: (\\w+)",
#     "cif_comercializadora": "CIF (\\w+)",
#     "direcci\u00f3n_comercializadora": "Domicilio Social: ([\\w ,]+)",
#     "cp_comercializadora": "Domicilio Social: .+?(\\d{5})",
#     "poblaci\u00f3n_comercializadora": "Domicilio Social: .+? \\d{5} (\\w+)",
#     "provincia_comercializadora": "provincia_comercializadora: (\\w+)",
#     "n\u00famero_factura": "N\u00ba factura: (\\w+)",
#     "inicio_periodo": "Periodo de Facturaci\u00f3n: del (\\d{2}/\\d{2}/\\d{4})",
#     "fin_periodo": "a (\\d{2}/\\d{2}/\\d{4})",
#     "importe_factura": "TOTAL IMPORTE FACTURA(\\d+,\\d{2}) \u20ac",
#     "fecha_cargo": "Fecha de cargo: (\\d{2} de \\w+ de \\d{4})",
#     "consumo_periodo": "Consumo\\n(\\d+ kWh)",
#     "potencia_contratada": "Potencia contratada: (\\d,\\d{3}) kW"
# }

# %%
import fitz  # PyMuPDF
import re
import json

def extract_text_from_pdf(file_path):
    doc = fitz.open(file_path)
    text = ""
    for page in doc:
        text += page.get_text()
    return text

def extract_fields(text):
    data = {}
    patterns = {
        "nombre_cliente": r"Titular del contrato: (\w+ [\w ]+)",
        "dni_cliente": r"NIF: (\w+)",
        "calle_cliente": r"Dirección de suministro: ([\w ,]+)",
        "cp_cliente": r"(\d{5})",
        "población_cliente": r"Dirección suministro: .+ (\d{5}) (\w+)",
        "provincia_cliente": r"provincia_cliente: (\w+)",
        "nombre_comercializadora": r"nombre_comercializadora: (\w+)",
        "cif_comercializadora": r"CIF (\w+)",
        "dirección_comercializadora": r"Domicilio Social: ([\w ,]+)",
        "cp_comercializadora": r"Domicilio Social: .+?(\d{5})",
        "población_comercializadora": r"Domicilio Social: .+? \d{5} (\w+)",
        "provincia_comercializadora": r"provincia_comercializadora: (\w+)",
        "número_factura": r"Nº factura: (\w+)",
        "inicio_periodo": r"Periodo de Facturación: del (\d{2}/\d{2}/\d{4})",
        "fin_periodo": r"a (\d{2}/\d{2}/\d{4})",
        "importe_factura": r"TOTAL IMPORTE FACTURA(\d+,\d{2}) €",
        "fecha_cargo": r"Fecha de cargo: (\d{2} de \w+ de \d{4})",
        "consumo_periodo": r"Consumo\n(\d+ kWh)",
        "potencia_contratada": r"Potencia contratada: (\d,\d{3}) kW"
    }
    
    for key, pattern in patterns.items():
        match = re.search(pattern, text)
        if match:
            data[key] = match.group(1)
        else:
            data[key] = "No encontrado"
    
    return data

def create_json(data):
    return json.dumps(data, indent=4, ensure_ascii=False)

# Proceso de ejemplo para un archivo PDF
pdf_text = extract_text_from_pdf("./training/factura_0.pdf") #CAMBIA LA RUTA Y EL NOMBRE DE ARCHIVO
extracted_data = extract_fields(pdf_text)
json_output = create_json(extracted_data)

print(json_output)
# Out:
# {
#     "nombre_cliente": "Conrado Daniel Iglesias ",
#     "dni_cliente": "73635161V",
#     "calle_cliente": "Calle la Solana, La Fueva, Huesca ",
#     "cp_cliente": "50436",
#     "población_cliente": "No encontrado",
#     "provincia_cliente": "No encontrado",
#     "nombre_comercializadora": "No encontrado",
#     "cif_comercializadora": "B90393497",
#     "dirección_comercializadora": "CRT",
#     "cp_comercializadora": "No encontrado",
#     "población_comercializadora": "No encontrado",
#     "provincia_comercializadora": "No encontrado",
#     "número_factura": "SV5043664894",
#     "inicio_periodo": "26/08/2018",
#     "fin_periodo": "25/09/2018",
#     "importe_factura": "No encontrado",
#     "fecha_cargo": "30 de septiembre de 2018",
#     "consumo_periodo": "No encontrado",
#     "potencia_contratada": "4,799"
# }

# %%
import fitz  # PyMuPDF
import re
import json

def extract_text_from_pdf(file_path):
    # Abre el archivo PDF y extrae todo el texto
    doc = fitz.open(file_path)
    text = ""
    for page in doc:
        text += page.get_text()
    return text

def parse_and_create_json(text):
    # Diccionario para almacenar los datos
    json_data = {}
    
    # Expresiones regulares para identificar cada campo relevante
    fields = {
        "nombre_cliente": [r"Titular del contrato: (.+)", r"Nombre: (.+)"],
        "dni_cliente": [r"NIF: (\w+)"],
        "calle_cliente": [r"Dirección de suministro: (.+)", r"Dirección suministro: (.+)"],
        "cp_cliente": [r"Dirección de suministro: .*, (\d{5})"],
        "población_cliente": [r"Dirección de suministro: .*, \d{5} (.+)",r"Dirección de suministro: [^,]*, ([^,]+),"],
        "provincia_cliente": [r"Dirección de suministro: .*, \d{5} .+, (.+)",r"Dirección de suministro: .*, \w+, (.+)"],
        "nombre_comercializadora": [r"comercializadora: (.+),"],
        "cif_comercializadora": [r"CIF (\w+)",],
        "dirección_comercializadora": [r"Domicilio Social: (.+)"],
        "cp_comercializadora": [r"Domicilio Social: .*, (\d{5})"],
        "población_comercializadora": [r"Domicilio Social: .*, \d{5} (.+)"],
        "provincia_comercializadora": [r"Domicilio Social: .*, \d{5} .+, (.+)"],
        "número_factura": [r"Nº factura: (\w+)"],
        "inicio_periodo": [r"Periodo de Facturación: del (\d{2}/\d{2}/\d{4})",r"Período de (\d{2}\.\d{2}\.\d{4})"],
        "fin_periodo": [r"a (\d{2}/\d{2}/\d{4})", r"a (\d{2}\.\d{2}\.\d{4})"],
        "importe_factura": [r"TOTAL IMPORTE FACTURA\s+(\d+,\d{2}) €",r"(\d+,\d{2})\s*€\s*Total a pagar"],
        "fecha_cargo": [r"Fecha de cargo: (\d{2} de \w+ de \d{4})", r"Fecha de cargo: (\d{2}\.\d{2}\.\d{4})"],
        "consumo_periodo": [r"Consumo en el periodo (\d+)",r"en el periodo\s(.+)",r"en el periodo\s+(\d+)\s+kWh"],
        "potencia_contratada": [r"Potencia contratada: (\d,\d{3}) kW",r"Término de potencia \(([\d,]+) kW\)"]
    }
    
    # Extrae cada campo usando su respectiva expresión regular
    for field, patterns in fields.items():
        found = False
        if not isinstance(patterns, list):
            patterns = [patterns]  # Convierte en lista si no es una lista
        for pattern in patterns:
            match = re.search(pattern, text, re.MULTILINE)
            if match:
                json_data[field] = match.group(1)
                found = True
                break  # Salir del bucle si se encuentra una coincidencia
        if not found:
            json_data[field] = "No encontrado"

    return json.dumps(json_data, indent=4, ensure_ascii=False)

# Uso del código
file_path = "./training/factura_0.pdf" #CAMBIA LA RUTA Y EL NOMBRE DE ARCHIVO
pdf_text = extract_text_from_pdf(file_path)
json_output = parse_and_create_json(pdf_text)

print(json_output)
# Out:
# {
#     "nombre_cliente": "Conrado Daniel Iglesias ",
#     "dni_cliente": "73635161V",
#     "calle_cliente": "Calle la Solana, La Fueva, Huesca ",
#     "cp_cliente": "No encontrado",
#     "población_cliente": "La Fueva",
#     "provincia_cliente": "No encontrado",
#     "nombre_comercializadora": "No encontrado",
#     "cif_comercializadora": "B90393497",
#     "dirección_comercializadora": "CRT.SEVILLA-MADRID, KM 524, CAMINO DE LA PASTORA ",
#     "cp_comercializadora": "No encontrado",
#     "población_comercializadora": "No encontrado",
#     "provincia_comercializadora": "No encontrado",
#     "número_factura": "SV5043664894",
#     "inicio_periodo": "26/08/2018",
#     "fin_periodo": "25/09/2018",
#     "importe_factura": "19,78",
#     "fecha_cargo": "30 de septiembre de 2018",
#     "consumo_periodo": "0",
#     "potencia_contratada": "4,799"
# }

# %%
#TODOS LOS ARCHIVOS EN JSON

import fitz  # PyMuPDF
import re
import json
import os

def extract_text_from_pdf(file_path):
    doc = fitz.open(file_path)
    text = ""
    for page in doc:
        text += page.get_text()
    return text

def parse_and_create_json(text):
    json_data = {}
    fields = {
        "nombre_cliente": [r"Titular del contrato: (.+)", r"Nombre: (.+)"],
        "dni_cliente": [r"NIF: (\w+)"],
        "calle_cliente": [r"Dirección de suministro: (.+)", r"Dirección suministro: (.+)"],
        "cp_cliente": [r"Dirección de suministro: .*, (\d{5})"],
        "población_cliente": [r"Dirección de suministro: .*, \d{5} (.+)",r"Dirección de suministro: [^,]*, ([^,]+),"],
        "provincia_cliente": [r"Dirección de suministro: .*, \d{5} .+, (.+)",r"Dirección de suministro: .*, \w+, (.+)"],
        "nombre_comercializadora": [r"comercializadora: (.+),"],
        "cif_comercializadora": [r"CIF (\w+)",],
        "dirección_comercializadora": [r"Domicilio Social: (.+)"],
        "cp_comercializadora": [r"Domicilio Social: .*, (\d{5})"],
        "población_comercializadora": [r"Domicilio Social: .*, \d{5} (.+)"],
        "provincia_comercializadora": [r"Domicilio Social: .*, \d{5} .+, (.+)"],
        "número_factura": [r"Nº factura: (\w+)"],
        "inicio_periodo": [r"Periodo de Facturación: del (\d{2}/\d{2}/\d{4})",r"Período de (\d{2}\.\d{2}\.\d{4})"],
        "fin_periodo": [r"a (\d{2}/\d{2}/\d{4})", r"a (\d{2}\.\d{2}\.\d{4})"],
        "importe_factura": [r"TOTAL IMPORTE FACTURA\s+(\d+,\d{2}) €",r"(\d+,\d{2})\s*€\s*Total a pagar"],
        "fecha_cargo": [r"Fecha de cargo: (\d{2} de \w+ de \d{4})", r"Fecha de cargo: (\d{2}\.\d{2}\.\d{4})"],
        "consumo_periodo": [r"Consumo en el periodo (\d+)",r"en el periodo\s(.+)",r"en el periodo\s+(\d+)\s+kWh"],
        "potencia_contratada": [r"Potencia contratada: (\d,\d{3}) kW",r"Término de potencia \(([\d,]+) kW\)"]
    }
    for field, patterns in fields.items():
        found = False
        for pattern in patterns:
            match = re.search(pattern, text, re.MULTILINE)
            if match:
                json_data[field] = match.group(1)
                found = True
                break
        if not found:
            json_data[field] = "No encontrado"
    return json_data

def process_all_pdfs(directory):
    all_data = []
    for filename in os.listdir(directory):
        if filename.endswith(".pdf"):
            file_path = os.path.join(directory, filename)
            pdf_text = extract_text_from_pdf(file_path)
            json_data = parse_and_create_json(pdf_text)
            all_data.append(json_data)
    return json.dumps(all_data, indent=4, ensure_ascii=False)

# Uso del código
directory = "./training"
json_output = process_all_pdfs(directory)
print(json_output)
# Out:
# [
#     {
#         "nombre_cliente": "Conrado Daniel Iglesias ",
#         "dni_cliente": "73635161V",
#         "calle_cliente": "Calle la Solana, La Fueva, Huesca ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "La Fueva",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B90393497",
#         "dirección_comercializadora": "CRT.SEVILLA-MADRID, KM 524, CAMINO DE LA PASTORA ",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "SV5043664894",
#         "inicio_periodo": "26/08/2018",
#         "fin_periodo": "25/09/2018",
#         "importe_factura": "19,78",
#         "fecha_cargo": "30 de septiembre de 2018",
#         "consumo_periodo": "0",
#         "potencia_contratada": "4,799"
#     },
#     {
#         "nombre_cliente": "LEONARDA JARAMILLO BÁEZ ",
#         "dni_cliente": "90237166R",
#         "calle_cliente": "Camino de los Pelendengues  ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "No encontrado",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "K9131055493",
#         "inicio_periodo": "12.05.2020",
#         "fin_periodo": "11.06.2020",
#         "importe_factura": "104,74",
#         "fecha_cargo": "16.06.2020",
#         "consumo_periodo": "No encontrado",
#         "potencia_contratada": "4,524"
#     },
#     {
#         "nombre_cliente": "No encontrado",
#         "dni_cliente": "33040846N",
#         "calle_cliente": "Calle de Sierra Gorda 33675 Aller ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B25267220",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "No encontrado",
#         "inicio_periodo": "No encontrado",
#         "fin_periodo": "No encontrado",
#         "importe_factura": "121,12",
#         "fecha_cargo": "05 de julio de 2017",
#         "consumo_periodo": "de facturación por el precio del término de energía del peaje de acceso) y la facturación por coste de la ",
#         "potencia_contratada": "No encontrado"
#     },
#     {
#         "nombre_cliente": "Hera Alcocer Zuleta ",
#         "dni_cliente": "72165903E",
#         "calle_cliente": "Calle de la Amapola, Hijes, Guadalajara ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Hijes",
#         "provincia_cliente": "Guadalajara ",
#         "nombre_comercializadora": "IE2 INNOVACION",
#         "cif_comercializadora": "B39829197",
#         "dirección_comercializadora": "C/ ISABEL TORRES, Nº25, 39011 - Cantabria ",
#         "cp_comercializadora": "39011",
#         "población_comercializadora": "- Cantabria ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "TO1016699250",
#         "inicio_periodo": "18/10/2008",
#         "fin_periodo": "17/11/2008",
#         "importe_factura": "82,43",
#         "fecha_cargo": "22 de noviembre de 2008",
#         "consumo_periodo": "256",
#         "potencia_contratada": "4,565"
#     },
#     {
#         "nombre_cliente": "No encontrado",
#         "dni_cliente": "18796498R",
#         "calle_cliente": "Calle del Triunfo 15149 Cabana de Bergantiños ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B66027731",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "No encontrado",
#         "inicio_periodo": "No encontrado",
#         "fin_periodo": "No encontrado",
#         "importe_factura": "314,86",
#         "fecha_cargo": "24 de octubre de 2008",
#         "consumo_periodo": "de facturación por el precio del término de energía del peaje de acceso) y la facturación por coste de la ",
#         "potencia_contratada": "No encontrado"
#     },
#     {
#         "nombre_cliente": "NORMA OCAMPO VALDIVA ",
#         "dni_cliente": "84225139J",
#         "calle_cliente": "Callejon de la Chitina, Chimillas, Huesca ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Chimillas",
#         "provincia_cliente": "Huesca ",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B85634350",
#         "dirección_comercializadora": "C/ VALLE DEL MORO, Nº13, 28660 - Madrid ",
#         "cp_comercializadora": "28660",
#         "población_comercializadora": "- Madrid ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "B4288861829",
#         "inicio_periodo": "29/11/2019",
#         "fin_periodo": "29/12/2019",
#         "importe_factura": "49,28",
#         "fecha_cargo": "03 de enero de 2020",
#         "consumo_periodo": "189",
#         "potencia_contratada": "3,417"
#     },
#     {
#         "nombre_cliente": "Clodoveo Mena Paladino ",
#         "dni_cliente": "80276656D",
#         "calle_cliente": "Calle del Limonero, Arjonilla, Jaén ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Arjonilla",
#         "provincia_cliente": "Jaén ",
#         "nombre_comercializadora": "KNET COMUNICACIONES",
#         "cif_comercializadora": "B26266106",
#         "dirección_comercializadora": "AVDA. CLUB DEPORTIVO, 55, 26007 - La Rioja ",
#         "cp_comercializadora": "26007",
#         "población_comercializadora": "- La Rioja ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "T2206947904",
#         "inicio_periodo": "07/05/2019",
#         "fin_periodo": "06/07/2019",
#         "importe_factura": "159,94",
#         "fecha_cargo": "11 de julio de 2019",
#         "consumo_periodo": "460",
#         "potencia_contratada": "3,868"
#     },
#     {
#         "nombre_cliente": "Ryan Taracena Escamilla ",
#         "dni_cliente": "39436973T",
#         "calle_cliente": "Calle Los Carros, Culleredo, A Coruña ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Culleredo",
#         "provincia_cliente": "A Coruña ",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B25616970",
#         "dirección_comercializadora": "C/ PAU COLL, 3, 25630 - Lérida ",
#         "cp_comercializadora": "25630",
#         "población_comercializadora": "- Lérida ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "C1273190823",
#         "inicio_periodo": "02/05/2000",
#         "fin_periodo": "01/06/2000",
#         "importe_factura": "27,14",
#         "fecha_cargo": "06 de junio de 2000",
#         "consumo_periodo": "30",
#         "potencia_contratada": "5,118"
#     },
#     {
#         "nombre_cliente": "Washington Vargas Lamas ",
#         "dni_cliente": "53098638X",
#         "calle_cliente": "Avenida Huerta Grande, Camarasa, Lleida ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Camarasa",
#         "provincia_cliente": "Lleida ",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "F03013331",
#         "dirección_comercializadora": "PASEO DE LA ESTACIÓN MÉDICO MANUEL SAMPER, 32-BJ, 03360 - ",
#         "cp_comercializadora": "03360",
#         "población_comercializadora": "- ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "L4325080393",
#         "inicio_periodo": "30/12/2011",
#         "fin_periodo": "28/02/2012",
#         "importe_factura": "40,01",
#         "fecha_cargo": "04 de marzo de 2012",
#         "consumo_periodo": "0",
#         "potencia_contratada": "5,110"
#     },
#     {
#         "nombre_cliente": "BETHSABE OLMO MONTALVO ",
#         "dni_cliente": "29429526Z",
#         "calle_cliente": "Calle de Benito Pérez Galdós, Carballeda ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Carballeda \nde Avia",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "LA UNIÓN ELECTRO INDUSTRIAL",
#         "cif_comercializadora": "B30001770",
#         "dirección_comercializadora": "C/ SAGRADO CORAZON DE JESUS, 17, 03330 - Alicante ",
#         "cp_comercializadora": "03330",
#         "población_comercializadora": "- Alicante ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "C7230448290",
#         "inicio_periodo": "30/03/2008",
#         "fin_periodo": "29/05/2008",
#         "importe_factura": "340,95",
#         "fecha_cargo": "03 de junio de 2008",
#         "consumo_periodo": "860",
#         "potencia_contratada": "4,626"
#     },
#     {
#         "nombre_cliente": "LÁZARO VELARDE HURTADO ",
#         "dni_cliente": "45182207H",
#         "calle_cliente": "Calle de la Guayaba, San Pedro del Pinatar, ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "San Pedro del Pinatar",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "APELES ELECTRICIDAD",
#         "cif_comercializadora": "B76654771",
#         "dirección_comercializadora": "C/ LAURA GROTE DE LA PUERTA, 8, 10, 38110 - Tenerife ",
#         "cp_comercializadora": "38110",
#         "población_comercializadora": "- Tenerife ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "ES2455391938",
#         "inicio_periodo": "01/10/2004",
#         "fin_periodo": "30/11/2004",
#         "importe_factura": "35,17",
#         "fecha_cargo": "05 de diciembre de 2004",
#         "consumo_periodo": "0",
#         "potencia_contratada": "3,813"
#     },
#     {
#         "nombre_cliente": "No encontrado",
#         "dni_cliente": "65329473C",
#         "calle_cliente": "Calle de Collado de la Mina 47209 San Martín de ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B52031168",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "No encontrado",
#         "inicio_periodo": "No encontrado",
#         "fin_periodo": "No encontrado",
#         "importe_factura": "376,60",
#         "fecha_cargo": "15 de julio de 2000",
#         "consumo_periodo": "de facturación por el precio del término de energía del peaje de acceso) y la facturación por coste de la ",
#         "potencia_contratada": "No encontrado"
#     },
#     {
#         "nombre_cliente": "Cristo Travieso Galván ",
#         "dni_cliente": "61780913S",
#         "calle_cliente": "Calle Albert Boadella  ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "GB245122493",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "PX5548492507",
#         "inicio_periodo": "09.11.2007",
#         "fin_periodo": "08.01.2008",
#         "importe_factura": "78,94",
#         "fecha_cargo": "13.01.2008",
#         "consumo_periodo": "No encontrado",
#         "potencia_contratada": "3,191"
#     },
#     {
#         "nombre_cliente": "CARMELA DARÍO GAMBOA ",
#         "dni_cliente": "24338786W",
#         "calle_cliente": "Calle de la Virgen de África, Hortigüela, ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Hortigüela",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "UNIC GLOBAL-LOGISTICS",
#         "cif_comercializadora": "B66277138",
#         "dirección_comercializadora": "C/ POMPEU FABRA, 13-2º DESPACHO 10, 08242 - Barcelona ",
#         "cp_comercializadora": "08242",
#         "población_comercializadora": "- Barcelona ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "CJ4228927656",
#         "inicio_periodo": "11/07/2006",
#         "fin_periodo": "09/09/2006",
#         "importe_factura": "88,48",
#         "fecha_cargo": "14 de septiembre de 2006",
#         "consumo_periodo": "182",
#         "potencia_contratada": "5,405"
#     },
#     {
#         "nombre_cliente": "LUCAS ALFARO SAVALA ",
#         "dni_cliente": "32950169R",
#         "calle_cliente": "Calle Fuente el Cobo, Mazarrón, Murcia ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Mazarrón",
#         "provincia_cliente": "Murcia ",
#         "nombre_comercializadora": "IBERDROLA CLIENTES ESPAÑA",
#         "cif_comercializadora": "A95758371",
#         "dirección_comercializadora": "PLAZA EUSKADI Nº5, 48009 - Vizcaya ",
#         "cp_comercializadora": "48009",
#         "población_comercializadora": "- Vizcaya ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "UC1821576432",
#         "inicio_periodo": "23/04/2020",
#         "fin_periodo": "22/06/2020",
#         "importe_factura": "300,33",
#         "fecha_cargo": "27 de junio de 2020",
#         "consumo_periodo": "1088",
#         "potencia_contratada": "3,714"
#     },
#     {
#         "nombre_cliente": "No encontrado",
#         "dni_cliente": "61047079L",
#         "calle_cliente": "Camino Entresierra 09339 Zael ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B25829904",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "No encontrado",
#         "inicio_periodo": "No encontrado",
#         "fin_periodo": "No encontrado",
#         "importe_factura": "137,80",
#         "fecha_cargo": "23 de diciembre de 2011",
#         "consumo_periodo": "de facturación por el precio del término de energía del peaje de acceso) y la facturación por coste de la ",
#         "potencia_contratada": "No encontrado"
#     },
#     {
#         "nombre_cliente": "Tecla Cornejo Velasco ",
#         "dni_cliente": "93327152Y",
#         "calle_cliente": "Calle Particular de las Eras  ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B09378720",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "R1435610031",
#         "inicio_periodo": "01.03.2000",
#         "fin_periodo": "30.04.2000",
#         "importe_factura": "315,49",
#         "fecha_cargo": "05.05.2000",
#         "consumo_periodo": "No encontrado",
#         "potencia_contratada": "4,640"
#     },
#     {
#         "nombre_cliente": "Ataúlfo Moscoa Mijares ",
#         "dni_cliente": "42322294V",
#         "calle_cliente": "Camino de Vilches, Coirós, A Coruña ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Coirós",
#         "provincia_cliente": "A Coruña ",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "A73987646",
#         "dirección_comercializadora": "AV. MIGUEL DE CERVANTES 23, 30009 - MURCIA ",
#         "cp_comercializadora": "30009",
#         "población_comercializadora": "- MURCIA ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "QY8482937505",
#         "inicio_periodo": "No encontrado",
#         "fin_periodo": "05/07/2005",
#         "importe_factura": "174,40",
#         "fecha_cargo": "10 de julio de 2005",
#         "consumo_periodo": "facturado ha sido de X,XX €  ",
#         "potencia_contratada": "2,864"
#     },
#     {
#         "nombre_cliente": "Simón Gamboa Ayala ",
#         "dni_cliente": "82447595R",
#         "calle_cliente": "Calle Valencia de Don Juan  ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B65960551",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "MO7666278721",
#         "inicio_periodo": "09.07.2012",
#         "fin_periodo": "08.08.2012",
#         "importe_factura": "63,84",
#         "fecha_cargo": "13.08.2012",
#         "consumo_periodo": "No encontrado",
#         "potencia_contratada": "5,284"
#     },
#     {
#         "nombre_cliente": "Diego Caballero Marcías ",
#         "dni_cliente": "73904992N",
#         "calle_cliente": "Calle de Sierra de Valdemeca, Medinaceli, ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Medinaceli",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "A78053147",
#         "dirección_comercializadora": "RONDA DE LA ",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "MN4040302628",
#         "inicio_periodo": "06/10/2006",
#         "fin_periodo": "05/12/2006",
#         "importe_factura": "158,90",
#         "fecha_cargo": "10 de diciembre de 2006",
#         "consumo_periodo": "448",
#         "potencia_contratada": "4,047"
#     },
#     {
#         "nombre_cliente": "TEODOMIRO NOVOA CARRANZA ",
#         "dni_cliente": "64427822S",
#         "calle_cliente": "Senda de Carlanchos  ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "No encontrado",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "C7742177472",
#         "inicio_periodo": "27.07.1993",
#         "fin_periodo": "26.08.1993",
#         "importe_factura": "92,81",
#         "fecha_cargo": "31.08.1993",
#         "consumo_periodo": "No encontrado",
#         "potencia_contratada": "5,407"
#     },
#     {
#         "nombre_cliente": "ESTRELLA ALAYÓN MARROQUÍ ",
#         "dni_cliente": "14794211J",
#         "calle_cliente": "Camino de la Casa El Garzo  ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "A08431090",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "YH9585589977",
#         "inicio_periodo": "02.05.1995",
#         "fin_periodo": "01.06.1995",
#         "importe_factura": "62,30",
#         "fecha_cargo": "06.06.1995",
#         "consumo_periodo": "No encontrado",
#         "potencia_contratada": "5,234"
#     },
#     {
#         "nombre_cliente": "No encontrado",
#         "dni_cliente": "43227791G",
#         "calle_cliente": "Calle Camino Real 08737 Torrelles de Foix ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "DK28113951",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "No encontrado",
#         "inicio_periodo": "No encontrado",
#         "fin_periodo": "No encontrado",
#         "importe_factura": "114,33",
#         "fecha_cargo": "05 de abril de 1992",
#         "consumo_periodo": "de facturación por el precio del término de energía del peaje de acceso) y la facturación por coste de la ",
#         "potencia_contratada": "No encontrado"
#     },
#     {
#         "nombre_cliente": "No encontrado",
#         "dni_cliente": "46786291J",
#         "calle_cliente": "Paraje de Fuente Cardena 40241 Cuéllar ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B84196997",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "No encontrado",
#         "inicio_periodo": "No encontrado",
#         "fin_periodo": "No encontrado",
#         "importe_factura": "75,66",
#         "fecha_cargo": "02 de junio de 2020",
#         "consumo_periodo": "de facturación por el precio del término de energía del peaje de acceso) y la facturación por coste de la ",
#         "potencia_contratada": "No encontrado"
#     },
#     {
#         "nombre_cliente": "PALOMA FONSECA GRIJALBA ",
#         "dni_cliente": "42713258G",
#         "calle_cliente": "Calle de Valcotos  ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B87095543",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "I1131220838",
#         "inicio_periodo": "10.08.2000",
#         "fin_periodo": "09.09.2000",
#         "importe_factura": "11,48",
#         "fecha_cargo": "14.09.2000",
#         "consumo_periodo": "No encontrado",
#         "potencia_contratada": "2,520"
#     },
#     {
#         "nombre_cliente": "Francisco Javier Chávez Mantilla ",
#         "dni_cliente": "74315109Q",
#         "calle_cliente": "Calle del Cantábrico  ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "No encontrado",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "BN7844757361",
#         "inicio_periodo": "04.05.1991",
#         "fin_periodo": "03.06.1991",
#         "importe_factura": "93,80",
#         "fecha_cargo": "08.06.1991",
#         "consumo_periodo": "No encontrado",
#         "potencia_contratada": "4,402"
#     },
#     {
#         "nombre_cliente": "Lucrecia Alanis Real ",
#         "dni_cliente": "37573120K",
#         "calle_cliente": "Calle del Corto  ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "No encontrado",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "U2896317531",
#         "inicio_periodo": "19.01.2002",
#         "fin_periodo": "20.03.2002",
#         "importe_factura": "316,46",
#         "fecha_cargo": "25.03.2002",
#         "consumo_periodo": "No encontrado",
#         "potencia_contratada": "4,463"
#     },
#     {
#         "nombre_cliente": "Ozana Alcázar Murillo ",
#         "dni_cliente": "63343450R",
#         "calle_cliente": "Calle Acacia, Mont-ral, Tarragona ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Mont-ral",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "PULSAR SERVICIOS ENERGÉTICOS",
#         "cif_comercializadora": "B91794941",
#         "dirección_comercializadora": "C/ REAL, 43, 41920 - Sevilla ",
#         "cp_comercializadora": "41920",
#         "población_comercializadora": "- Sevilla ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "S5998278264",
#         "inicio_periodo": "17/01/2012",
#         "fin_periodo": "16/02/2012",
#         "importe_factura": "61,46",
#         "fecha_cargo": "21 de febrero de 2012",
#         "consumo_periodo": "226",
#         "potencia_contratada": "3,741"
#     },
#     {
#         "nombre_cliente": "No encontrado",
#         "dni_cliente": "45439163H",
#         "calle_cliente": "Calle del Marqués de Hoyos 46016 Tavernes Blanques ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B37500238",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "No encontrado",
#         "inicio_periodo": "No encontrado",
#         "fin_periodo": "No encontrado",
#         "importe_factura": "100,29",
#         "fecha_cargo": "10 de noviembre de 2014",
#         "consumo_periodo": "de facturación por el precio del término de energía del peaje de acceso) y la facturación por coste de la ",
#         "potencia_contratada": "No encontrado"
#     },
#     {
#         "nombre_cliente": "ROBINSON SÁNCHEZ VELA ",
#         "dni_cliente": "45498212A",
#         "calle_cliente": "Calle del Arquitecto Sánchez Arcas  ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "758",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "T9396049062",
#         "inicio_periodo": "09.08.2011",
#         "fin_periodo": "08.09.2011",
#         "importe_factura": "244,35",
#         "fecha_cargo": "13.09.2011",
#         "consumo_periodo": "No encontrado",
#         "potencia_contratada": "2,863"
#     },
#     {
#         "nombre_cliente": "JOVINO CUÉLLAR CARVAJAL ",
#         "dni_cliente": "40381701A",
#         "calle_cliente": "Calle Luis Feito  ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "No encontrado",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "Y2326660743",
#         "inicio_periodo": "25.10.1993",
#         "fin_periodo": "24.12.1993",
#         "importe_factura": "246,47",
#         "fecha_cargo": "29.12.1993",
#         "consumo_periodo": "No encontrado",
#         "potencia_contratada": "2,566"
#     },
#     {
#         "nombre_cliente": "Primo Aguirre Velásquez ",
#         "dni_cliente": "96652465W",
#         "calle_cliente": "Pasaje de Doña Carlota, Caleruela, Toledo ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Caleruela",
#         "provincia_cliente": "Toledo ",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B18831842",
#         "dirección_comercializadora": "PASEO DEL VIOLÓN 25  LOCAL 8/9, 18006 - Granada ",
#         "cp_comercializadora": "18006",
#         "población_comercializadora": "- Granada ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "AZ1221159397",
#         "inicio_periodo": "01/04/1993",
#         "fin_periodo": "01/05/1993",
#         "importe_factura": "88,58",
#         "fecha_cargo": "06 de mayo de 1993",
#         "consumo_periodo": "348",
#         "potencia_contratada": "2,495"
#     },
#     {
#         "nombre_cliente": "KEVIN LOSADA ALANIS ",
#         "dni_cliente": "14404121A",
#         "calle_cliente": "Calle Serventia, Benamejí, Córdoba ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Benamejí",
#         "provincia_cliente": "Córdoba ",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B87579769",
#         "dirección_comercializadora": "PS. DE LA HABANA, 70, 28036 - Madrid ",
#         "cp_comercializadora": "28036",
#         "población_comercializadora": "- Madrid ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "YE4274714527",
#         "inicio_periodo": "07/06/2010",
#         "fin_periodo": "07/07/2010",
#         "importe_factura": "43,24",
#         "fecha_cargo": "12 de julio de 2010",
#         "consumo_periodo": "109",
#         "potencia_contratada": "3,113"
#     },
#     {
#         "nombre_cliente": "MALCOLM ROMÁN MONTALVO ",
#         "dni_cliente": "45949985X",
#         "calle_cliente": "Camino del Arca, Torre del Bierzo, León ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Torre del Bierzo",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B19556299",
#         "dirección_comercializadora": "C/ CUERNAVACA, 43 POL. IND.  SAN LUIS, 29006 - Málaga ",
#         "cp_comercializadora": "29006",
#         "población_comercializadora": "- Málaga ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "B8537057781",
#         "inicio_periodo": "25/12/2003",
#         "fin_periodo": "23/02/2004",
#         "importe_factura": "187,45",
#         "fecha_cargo": "28 de febrero de 2004",
#         "consumo_periodo": "586",
#         "potencia_contratada": "3,519"
#     },
#     {
#         "nombre_cliente": "Silvana Parra Llano ",
#         "dni_cliente": "78756554T",
#         "calle_cliente": "Avenida del Montepríncipe  ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B36878510",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "M1526772068",
#         "inicio_periodo": "30.11.2008",
#         "fin_periodo": "29.01.2009",
#         "importe_factura": "349,10",
#         "fecha_cargo": "03.02.2009",
#         "consumo_periodo": "No encontrado",
#         "potencia_contratada": "2,536"
#     },
#     {
#         "nombre_cliente": "Atanasia Luna Arriaga ",
#         "dni_cliente": "38744649E",
#         "calle_cliente": "Camino el Vinote, Querol, Tarragona ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Querol",
#         "provincia_cliente": "Tarragona ",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B08280061",
#         "dirección_comercializadora": "8 RUE DES ACACIAS,  - Extranjero ",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "K6776826644",
#         "inicio_periodo": "08/10/1999",
#         "fin_periodo": "06/11/1999",
#         "importe_factura": "141,28",
#         "fecha_cargo": "11 de noviembre de 1999",
#         "consumo_periodo": "530",
#         "potencia_contratada": "3,583"
#     },
#     {
#         "nombre_cliente": "LEANDRA MEDINA OLIVARES ",
#         "dni_cliente": "83238613A",
#         "calle_cliente": "Calle de Miguel Delibes, Candamo, Asturias ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Candamo",
#         "provincia_cliente": "Asturias ",
#         "nombre_comercializadora": "GDF SUEZ COMERCIALIZADORA",
#         "cif_comercializadora": "A82808007",
#         "dirección_comercializadora": "C/ GOYA, Nº 24, 3ª PLANTA, 28001 - Madrid ",
#         "cp_comercializadora": "28001",
#         "población_comercializadora": "- Madrid ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "DS6614737656",
#         "inicio_periodo": "07/08/1993",
#         "fin_periodo": "06/09/1993",
#         "importe_factura": "97,54",
#         "fecha_cargo": "11 de septiembre de 1993",
#         "consumo_periodo": "290",
#         "potencia_contratada": "4,666"
#     },
#     {
#         "nombre_cliente": "LEOCRICIA ZULETA NOVOA ",
#         "dni_cliente": "58986620S",
#         "calle_cliente": "Travesia del Condado de Treviño, Santas ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Santas \nMartas",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "F94090792",
#         "dirección_comercializadora": "RUA PEDRAL 36, BARBEITOS, 36619 - Pontevedra ",
#         "cp_comercializadora": "36619",
#         "población_comercializadora": "- Pontevedra ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "R8978802834",
#         "inicio_periodo": "09/11/2005",
#         "fin_periodo": "08/01/2006",
#         "importe_factura": "28,33",
#         "fecha_cargo": "13 de enero de 2006",
#         "consumo_periodo": "0",
#         "potencia_contratada": "2,994"
#     },
#     {
#         "nombre_cliente": "Mila Daniel Salas ",
#         "dni_cliente": "88846004V",
#         "calle_cliente": "Calle de la Carpintería, Lomoviejo, ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Lomoviejo",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "CONTALLUM ENERGIA",
#         "cif_comercializadora": "B98898240",
#         "dirección_comercializadora": "C/REINA NUM 3, 46800 - VALENCIA ",
#         "cp_comercializadora": "46800",
#         "población_comercializadora": "- VALENCIA ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "F5100560518",
#         "inicio_periodo": "22/07/2000",
#         "fin_periodo": "20/09/2000",
#         "importe_factura": "413,24",
#         "fecha_cargo": "25 de septiembre de 2000",
#         "consumo_periodo": "1316",
#         "potencia_contratada": "3,778"
#     },
#     {
#         "nombre_cliente": "VICENTA CALLES LEYVA ",
#         "dni_cliente": "77432649K",
#         "calle_cliente": "Carretera de los Hoyos A  ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "A98493125",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "J5810999038",
#         "inicio_periodo": "17.12.2002",
#         "fin_periodo": "15.02.2003",
#         "importe_factura": "241,32",
#         "fecha_cargo": "20.02.2003",
#         "consumo_periodo": "No encontrado",
#         "potencia_contratada": "5,289"
#     },
#     {
#         "nombre_cliente": "ROSAMUNDA VALES RIVAS ",
#         "dni_cliente": "95886381W",
#         "calle_cliente": "Calle del Río Jordán  ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "A95554630",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "F3410447867",
#         "inicio_periodo": "25.10.2020",
#         "fin_periodo": "24.11.2020",
#         "importe_factura": "69,19",
#         "fecha_cargo": "29.11.2020",
#         "consumo_periodo": "No encontrado",
#         "potencia_contratada": "2,967"
#     },
#     {
#         "nombre_cliente": "Peregrina Páez Becerril ",
#         "dni_cliente": "13772783S",
#         "calle_cliente": "Camino del Pintado, Valverde de los ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Valverde de los \nArroyos",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "TRACTAMENT I SELECCIÓ DE RESIDUS",
#         "cif_comercializadora": "A08800880",
#         "dirección_comercializadora": "AVDA. EDUARD MARISTANY, 44, 08930 - Barcelona ",
#         "cp_comercializadora": "08930",
#         "población_comercializadora": "- Barcelona ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "J1453030892",
#         "inicio_periodo": "05/02/2020",
#         "fin_periodo": "05/04/2020",
#         "importe_factura": "46,88",
#         "fecha_cargo": "10 de abril de 2020",
#         "consumo_periodo": "0",
#         "potencia_contratada": "4,847"
#     },
#     {
#         "nombre_cliente": "No encontrado",
#         "dni_cliente": "62426172D",
#         "calle_cliente": "Calle Polígono Industrial 31698 Esteribar ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B83160994",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "No encontrado",
#         "inicio_periodo": "No encontrado",
#         "fin_periodo": "No encontrado",
#         "importe_factura": "76,09",
#         "fecha_cargo": "25 de marzo de 2010",
#         "consumo_periodo": "de facturación por el precio del término de energía del peaje de acceso) y la facturación por coste de la ",
#         "potencia_contratada": "No encontrado"
#     },
#     {
#         "nombre_cliente": "LILIAN RESTREPO MORILLO ",
#         "dni_cliente": "90764148F",
#         "calle_cliente": "Calle de Fernando Lázaro Carreter, Lorca, ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Lorca",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B98729486",
#         "dirección_comercializadora": "C/BAIXADA DE L'ESTACIO 9-3-3, 46800 - VALENCIA ",
#         "cp_comercializadora": "46800",
#         "población_comercializadora": "- VALENCIA ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "B2684781118",
#         "inicio_periodo": "No encontrado",
#         "fin_periodo": "18/05/2007",
#         "importe_factura": "12,30",
#         "fecha_cargo": "23 de mayo de 2007",
#         "consumo_periodo": "facturado ha sido de X,XX €  ",
#         "potencia_contratada": "2,674"
#     },
#     {
#         "nombre_cliente": "LEODEGARIO LINES SALDAÑA ",
#         "dni_cliente": "31089278V",
#         "calle_cliente": "Callejon de los Herreros  ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B27779818",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "J2920028511",
#         "inicio_periodo": "20.05.2001",
#         "fin_periodo": "19.06.2001",
#         "importe_factura": "61,17",
#         "fecha_cargo": "24.06.2001",
#         "consumo_periodo": "No encontrado",
#         "potencia_contratada": "4,163"
#     },
#     {
#         "nombre_cliente": "HOMERO FIGUERAS QUEVEDO ",
#         "dni_cliente": "30123287A",
#         "calle_cliente": "Parque del Cerro Tío Pío, La Vilella Baixa, ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "La Vilella Baixa",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "DE815824732",
#         "dirección_comercializadora": "KURFÜRSTENDAMM 194 HAUS CUMBERLAND, 10707 - BERLIN ",
#         "cp_comercializadora": "10707",
#         "población_comercializadora": "- BERLIN ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "N7621886406",
#         "inicio_periodo": "17/06/2015",
#         "fin_periodo": "16/08/2015",
#         "importe_factura": "227,86",
#         "fecha_cargo": "21 de agosto de 2015",
#         "consumo_periodo": "548",
#         "potencia_contratada": "5,240"
#     },
#     {
#         "nombre_cliente": "Visitación Frías Salgado ",
#         "dni_cliente": "35216999C",
#         "calle_cliente": "Calle Buril, Simancas, Valladolid ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Simancas",
#         "provincia_cliente": "Valladolid ",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B36026375",
#         "dirección_comercializadora": "PLAZA DOCTOR CARÚS 7, 1º C, 36600 - Pontevedra ",
#         "cp_comercializadora": "36600",
#         "población_comercializadora": "- Pontevedra ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "YT3681997689",
#         "inicio_periodo": "18/01/2006",
#         "fin_periodo": "17/02/2006",
#         "importe_factura": "156,44",
#         "fecha_cargo": "22 de febrero de 2006",
#         "consumo_periodo": "550",
#         "potencia_contratada": "2,449"
#     },
#     {
#         "nombre_cliente": "FLAVIO VALDÉS JARAMILLO ",
#         "dni_cliente": "61464175X",
#         "calle_cliente": "Av San Antonio Maria Claret, Taragudo, ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Taragudo",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "F55091367",
#         "dirección_comercializadora": "C/ PIC DE PEGUERA, 15 ESC. A, PLANTA 1, PORTA 16, 17003 - Gerona ",
#         "cp_comercializadora": "17003",
#         "población_comercializadora": "- Gerona ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "T4303502616",
#         "inicio_periodo": "06/04/2001",
#         "fin_periodo": "06/05/2001",
#         "importe_factura": "18,12",
#         "fecha_cargo": "11 de mayo de 2001",
#         "consumo_periodo": "0",
#         "potencia_contratada": "4,411"
#     },
#     {
#         "nombre_cliente": "Emilio Cevallos Perdomo ",
#         "dni_cliente": "20711498K",
#         "calle_cliente": "Avenida de las Vegas, Serradilla del Arroyo, ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Serradilla del Arroyo",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "VILLAR MIR ENERGÍA",
#         "cif_comercializadora": "B85253888",
#         "dirección_comercializadora": "PASEO DE LA CASTELLANA 259-D, PLANTA 47, 28046 - Madrid ",
#         "cp_comercializadora": "28046",
#         "población_comercializadora": "- Madrid ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "Z4162318977",
#         "inicio_periodo": "12/09/1995",
#         "fin_periodo": "11/11/1995",
#         "importe_factura": "215,83",
#         "fecha_cargo": "16 de noviembre de 1995",
#         "consumo_periodo": "748",
#         "potencia_contratada": "4,096"
#     },
#     {
#         "nombre_cliente": "LEONILDA MENESES SOZA ",
#         "dni_cliente": "71398288D",
#         "calle_cliente": "Calle el Ruiseñor, Fuente de Pedro ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Fuente de Pedro \nNaharro",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "5617841001",
#         "dirección_comercializadora": "Viale Regina Margherita, 125,  - Extranjero ",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "VW5920460644",
#         "inicio_periodo": "14/11/2015",
#         "fin_periodo": "14/12/2015",
#         "importe_factura": "33,93",
#         "fecha_cargo": "19 de diciembre de 2015",
#         "consumo_periodo": "117",
#         "potencia_contratada": "2,790"
#     },
#     {
#         "nombre_cliente": "Sonia Troncoso Macedo ",
#         "dni_cliente": "29537464J",
#         "calle_cliente": "Paraje Masía Fuentecillas  ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B96599006",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "NE6448710263",
#         "inicio_periodo": "23.09.2000",
#         "fin_periodo": "23.10.2000",
#         "importe_factura": "109,35",
#         "fecha_cargo": "28.10.2000",
#         "consumo_periodo": "No encontrado",
#         "potencia_contratada": "5,349"
#     },
#     {
#         "nombre_cliente": "VICTORIA RAMÓN SEGURA ",
#         "dni_cliente": "80290929E",
#         "calle_cliente": "Plaza de Abogados de Atocha, Mugardos, A ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Mugardos",
#         "provincia_cliente": "A ",
#         "nombre_comercializadora": "LUZDEAQUI",
#         "cif_comercializadora": "A09516717",
#         "dirección_comercializadora": "C/ SANTANDER, Nº11, 1º OFICINA Nº2, 09006 - Burgos ",
#         "cp_comercializadora": "09006",
#         "población_comercializadora": "- Burgos ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "K9267093338",
#         "inicio_periodo": "02/08/2009",
#         "fin_periodo": "01/09/2009",
#         "importe_factura": "114,18",
#         "fecha_cargo": "06 de septiembre de 2009",
#         "consumo_periodo": "459",
#         "potencia_contratada": "5,610"
#     },
#     {
#         "nombre_cliente": "Learco Páramo Uveda ",
#         "dni_cliente": "43777298H",
#         "calle_cliente": "Calle de Calatayud  ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B87828679",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
# ...
#         "potencia_contratada": "4,723"
#     },
#     {
#         "nombre_cliente": "Branca Torre Manzanal ",
#         "dni_cliente": "10469191M",
#         "calle_cliente": "Calle Colada de Pozuelo, Santa Maria de ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Santa Maria de \nMerlñs",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B32487548",
#         "dirección_comercializadora": "LG. SANTA CRUZ DE ARRABALDO S/N, 32990 - ORENSE ",
#         "cp_comercializadora": "32990",
#         "población_comercializadora": "- ORENSE ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "MU6100443279",
#         "inicio_periodo": "04/05/1997",
#         "fin_periodo": "03/06/1997",
#         "importe_factura": "26,23",
#         "fecha_cargo": "08 de junio de 1997",
#         "consumo_periodo": "32",
#         "potencia_contratada": "4,539"
#     },
#     {
#         "nombre_cliente": "Cristóbal Taracena Gillén ",
#         "dni_cliente": "39911901R",
#         "calle_cliente": "Calle Verano, Ribadedeva, Asturias ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Ribadedeva",
#         "provincia_cliente": "Asturias ",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B75035592",
#         "dirección_comercializadora": "AVENIDA ERREKALDE Nº33 3 PLANTA, 20018 - Guipúzcoa ",
#         "cp_comercializadora": "20018",
#         "población_comercializadora": "- Guipúzcoa ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "PG8243683678",
#         "inicio_periodo": "No encontrado",
#         "fin_periodo": "03/03/2020",
#         "importe_factura": "209,29",
#         "fecha_cargo": "08 de marzo de 2020",
#         "consumo_periodo": "facturado ha sido de X,XX €  ",
#         "potencia_contratada": "2,771"
#     },
#     {
#         "nombre_cliente": "WERTHER PERAZA IBÁÑEZ ",
#         "dni_cliente": "39440254S",
#         "calle_cliente": "Calle El Ripio  ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "No encontrado",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "Q5145026333",
#         "inicio_periodo": "12.05.2021",
#         "fin_periodo": "11.07.2021",
#         "importe_factura": "197,66",
#         "fecha_cargo": "16.07.2021",
#         "consumo_periodo": "No encontrado",
#         "potencia_contratada": "5,129"
#     },
#     {
#         "nombre_cliente": "REMIGIO CASAS OLMEDO ",
#         "dni_cliente": "62555131F",
#         "calle_cliente": "Calle Alejo Carpentier, A Pobra de Trives, ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "A Pobra de Trives",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "EDP-ENERGÍAS DE PORTUGAL",
#         "cif_comercializadora": "PT500697256",
#         "dirección_comercializadora": "Praça Marquês de Pombal nº 13,  - Extranjero ",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "LG6539976672",
#         "inicio_periodo": "27/01/2010",
#         "fin_periodo": "26/02/2010",
#         "importe_factura": "103,42",
#         "fecha_cargo": "03 de marzo de 2010",
#         "consumo_periodo": "341",
#         "potencia_contratada": "3,531"
#     },
#     {
#         "nombre_cliente": "OZANA URIETA ZABALETA ",
#         "dni_cliente": "75097842J",
#         "calle_cliente": "Calle de Mijas, Ezkurra, Navarra ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Ezkurra",
#         "provincia_cliente": "Navarra ",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B95783924",
#         "dirección_comercializadora": "C/ ALAMEDA DE LAS LLANAS 23, LOCAL DCHA, 48910 - Bizkaia ",
#         "cp_comercializadora": "48910",
#         "población_comercializadora": "- Bizkaia ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "I4777052730",
#         "inicio_periodo": "19/10/2007",
#         "fin_periodo": "18/12/2007",
#         "importe_factura": "37,56",
#         "fecha_cargo": "23 de diciembre de 2007",
#         "consumo_periodo": "20",
#         "potencia_contratada": "4,016"
#     },
#     {
#         "nombre_cliente": "ORIOL MEJÍA ZAMUDIO ",
#         "dni_cliente": "30402100X",
#         "calle_cliente": "Calle Guillermo Cabrera Infante, ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "\nCarboneras de Guadazaón",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "ARAN ENERGIA",
#         "cif_comercializadora": "B25823006",
#         "dirección_comercializadora": "C/ MAYOR Nº 52, 25550 - Lérida ",
#         "cp_comercializadora": "25550",
#         "población_comercializadora": "- Lérida ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "K5032336559",
#         "inicio_periodo": "12/05/2011",
#         "fin_periodo": "11/07/2011",
#         "importe_factura": "347,49",
#         "fecha_cargo": "16 de julio de 2011",
#         "consumo_periodo": "1384",
#         "potencia_contratada": "5,415"
#     },
#     {
#         "nombre_cliente": "CEFERINO JIMÉNEZ FARÍAS ",
#         "dni_cliente": "92279676L",
#         "calle_cliente": "Plaza de Antonio Blanco, Nules, ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Nules",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "GB735547907",
#         "dirección_comercializadora": "80 Victoria Street, Cardinal Place,  - Extranjero ",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "D3391442484",
#         "inicio_periodo": "22/03/2017",
#         "fin_periodo": "21/04/2017",
#         "importe_factura": "60,46",
#         "fecha_cargo": "26 de abril de 2017",
#         "consumo_periodo": "190",
#         "potencia_contratada": "4,652"
#     },
#     {
#         "nombre_cliente": "No encontrado",
#         "dni_cliente": "34199367T",
#         "calle_cliente": "Calle Castro 19277 Cincovillas ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B98729486",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "No encontrado",
#         "inicio_periodo": "No encontrado",
#         "fin_periodo": "No encontrado",
#         "importe_factura": "110,25",
#         "fecha_cargo": "23 de mayo de 2004",
#         "consumo_periodo": "de facturación por el precio del término de energía del peaje de acceso) y la facturación por coste de la ",
#         "potencia_contratada": "No encontrado"
#     },
#     {
#         "nombre_cliente": "Yerma Cervantes Valdiva ",
#         "dni_cliente": "78171584N",
#         "calle_cliente": "Calle del Ciclón, Madrigal de la Vera, ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Madrigal de la Vera",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B85634350",
#         "dirección_comercializadora": "C/ VALLE DEL MORO, Nº13, 28660 - Madrid ",
#         "cp_comercializadora": "28660",
#         "población_comercializadora": "- Madrid ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "R6785775480",
#         "inicio_periodo": "18/09/2019",
#         "fin_periodo": "17/11/2019",
#         "importe_factura": "252,09",
#         "fecha_cargo": "22 de noviembre de 2019",
#         "consumo_periodo": "754",
#         "potencia_contratada": "4,213"
#     },
#     {
#         "nombre_cliente": "No encontrado",
#         "dni_cliente": "81135385X",
#         "calle_cliente": "Calle de Hartzenbusch 32450 Cenlle ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B90472028",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "No encontrado",
#         "inicio_periodo": "No encontrado",
#         "fin_periodo": "No encontrado",
#         "importe_factura": "60,82",
#         "fecha_cargo": "01 de octubre de 1994",
#         "consumo_periodo": "de facturación por el precio del término de energía del peaje de acceso) y la facturación por coste de la ",
#         "potencia_contratada": "No encontrado"
#     },
#     {
#         "nombre_cliente": "No encontrado",
#         "dni_cliente": "56719070N",
#         "calle_cliente": "Calle de Valdegovia 27744 Riotorto ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B54985353",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "No encontrado",
#         "inicio_periodo": "No encontrado",
#         "fin_periodo": "No encontrado",
#         "importe_factura": "104,42",
#         "fecha_cargo": "15 de diciembre de 1999",
#         "consumo_periodo": "de facturación por el precio del término de energía del peaje de acceso) y la facturación por coste de la ",
#         "potencia_contratada": "No encontrado"
#     },
#     {
#         "nombre_cliente": "No encontrado",
#         "dni_cliente": "26727330L",
#         "calle_cliente": "Pasaje San Juan 25737 Bassella ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B37547619",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "No encontrado",
#         "inicio_periodo": "No encontrado",
#         "fin_periodo": "No encontrado",
#         "importe_factura": "109,52",
#         "fecha_cargo": "02 de enero de 1996",
#         "consumo_periodo": "de facturación por el precio del término de energía del peaje de acceso) y la facturación por coste de la ",
#         "potencia_contratada": "No encontrado"
#     },
#     {
#         "nombre_cliente": "No encontrado",
#         "dni_cliente": "20980142W",
#         "calle_cliente": "Paseo de José Ignacio de Ibarrola 22440 Benasque ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "F03013356",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "No encontrado",
#         "inicio_periodo": "No encontrado",
#         "fin_periodo": "No encontrado",
#         "importe_factura": "62,52",
#         "fecha_cargo": "29 de enero de 1994",
#         "consumo_periodo": "de facturación por el precio del término de energía del peaje de acceso) y la facturación por coste de la ",
#         "potencia_contratada": "No encontrado"
#     },
#     {
#         "nombre_cliente": "Petrona Uribe Naranjo ",
#         "dni_cliente": "26934250P",
#         "calle_cliente": "Lugar Valhondo y los Velascos, Alcanó, ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Alcanó",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B95960365",
#         "dirección_comercializadora": "PZ CANTABRIA Nº2 2º A IZ, 48902 - BIZKAIA ",
#         "cp_comercializadora": "48902",
#         "población_comercializadora": "- BIZKAIA ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "U2093855017",
#         "inicio_periodo": "13/06/2011",
#         "fin_periodo": "13/07/2011",
#         "importe_factura": "119,20",
#         "fecha_cargo": "18 de julio de 2011",
#         "consumo_periodo": "447",
#         "potencia_contratada": "4,406"
#     },
#     {
#         "nombre_cliente": "CELESTINA TREMINIO VALLEJO ",
#         "dni_cliente": "19020297X",
#         "calle_cliente": "Carretera de Barajas, Villarroya del ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Villarroya del \nCampo",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B47732334",
#         "dirección_comercializadora": "C/ HIDRÓGENO, 11, 47012 - Valladolid ",
#         "cp_comercializadora": "47012",
#         "población_comercializadora": "- Valladolid ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "IR1574483752",
#         "inicio_periodo": "No encontrado",
#         "fin_periodo": "16/06/1994",
#         "importe_factura": "29,30",
#         "fecha_cargo": "21 de junio de 1994",
#         "consumo_periodo": "facturado ha sido de X,XX €  ",
#         "potencia_contratada": "2,472"
#     },
#     {
#         "nombre_cliente": "No encontrado",
#         "dni_cliente": "32031898M",
#         "calle_cliente": "Calle Siete Abanicos 02514 Tobarra ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "No encontrado",
#         "provincia_cliente": "No encontrado",
#         "nombre_comercializadora": "No encontrado",
#         "cif_comercializadora": "B40563520",
#         "dirección_comercializadora": "No encontrado",
#         "cp_comercializadora": "No encontrado",
#         "población_comercializadora": "No encontrado",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "No encontrado",
#         "inicio_periodo": "No encontrado",
#         "fin_periodo": "No encontrado",
#         "importe_factura": "70,79",
#         "fecha_cargo": "28 de julio de 2008",
#         "consumo_periodo": "de facturación por el precio del término de energía del peaje de acceso) y la facturación por coste de la ",
#         "potencia_contratada": "No encontrado"
#     },
#     {
#         "nombre_cliente": "KIRA GAITÁN QUESADA ",
#         "dni_cliente": "32433787S",
#         "calle_cliente": "Calle de Briones, Málaga, Málaga ",
#         "cp_cliente": "No encontrado",
#         "población_cliente": "Málaga",
#         "provincia_cliente": "Málaga ",
#         "nombre_comercializadora": "CANARY BIOENERGY",
#         "cif_comercializadora": "B38920500",
#         "dirección_comercializadora": "C/ VILLALBA HERVÁS, 2 - 7º, 38002 - Tenerife ",
#         "cp_comercializadora": "38002",
#         "población_comercializadora": "- Tenerife ",
#         "provincia_comercializadora": "No encontrado",
#         "número_factura": "BD9767921453",
#         "inicio_periodo": "06/02/1997",
#         "fin_periodo": "08/03/1997",
#         "importe_factura": "114,12",
#         "fecha_cargo": "13 de marzo de 1997",
#         "consumo_periodo": "342",
#         "potencia_contratada": "3,813"
#     }
# ]

# %%
#TODOS LOS ARCHIVOS EN UN CSV PARA VER QUÉ HAY QUE CAMBIAR

import fitz  # PyMuPDF
import re
import csv
import os

def extract_text_from_pdf(file_path):
    doc = fitz.open(file_path)
    text = ""
    for page in doc:
        text += page.get_text()
    return text

def parse_and_create_data(text, filename):
    data = {"nombre_archivo": filename}  # Incluir el nombre del archivo en el diccionario de datos
    fields = {
        "nombre_cliente": [r"Titular del contrato: (.+)", r"Nombre: (.+)"],
        "dni_cliente": [r"NIF: (\w+)"],
        "calle_cliente": [r"Dirección de suministro: (.+)", r"Dirección suministro: (.+)"],
        "cp_cliente": [r"Dirección de suministro: .*, (\d{5})"],
        "población_cliente": [r"Dirección de suministro: .*, \d{5} (.+)", r"Dirección de suministro: [^,]*, ([^,]+),"],
        "provincia_cliente": [r"Dirección de suministro: .*, \d{5} .+, (.+)", r"Dirección de suministro: .*, \w+, (.+)"],
        "nombre_comercializadora": [r"comercializadora: (.+),"],
        "cif_comercializadora": [r"CIF (\w+)"],
        "dirección_comercializadora": [r"Domicilio Social: (.+)"],
        "cp_comercializadora": [r"Domicilio Social: .*, (\d{5})"],
        "población_comercializadora": [r"Domicilio Social: .*, \d{5} (.+)"],
        "provincia_comercializadora": [r"Domicilio Social: .*, \d{5} .+, (.+)"],
        "número_factura": [r"Nº factura: (\w+)"],
        "inicio_periodo": [r"Periodo de Facturación: del (\d{2}/\d{2}/\d{4})", r"Período de (\d{2}\.\d{2}\.\d{4})"],
        "fin_periodo": [r"a (\d{2}/\d{2}/\d{4})", r"a (\d{2}\.\d{2}\.\d{4})"],
        "importe_factura": [r"TOTAL IMPORTE FACTURA\s+(\d+,\d{2}) €", r"(\d+,\d{2})\s*€\s*Total a pagar"],
        "fecha_cargo": [r"Fecha de cargo: (\d{2} de \w+ de \d{4})", r"Fecha de cargo: (\d{2}\.\d{2}\.\d{4})"],
        "consumo_periodo": [r"Consumo en el periodo (\d+)", r"en el periodo\s(.+)", r"en el periodo\s+(\d+)\s+kWh"],
        "potencia_contratada": [r"Potencia contratada: (\d,\d{3}) kW", r"Término de potencia \(([\d,]+) kW\)"]
    }
    for field, patterns in fields.items():
        found = False
        for pattern in patterns:
            match = re.search(pattern, text, re.MULTILINE)
            if match:
                data[field] = match.group(1)
                found = True
                break
        if not found:
            data[field] = "No encontrado"
    return data

def process_all_pdfs(directory, output_csv_file):
    all_data = []
    header = list(parse_and_create_data("", "").keys())  # Extrae las claves para el encabezado CSV, añadiendo el nombre del archivo
    for filename in os.listdir(directory):
        if filename.endswith(".pdf"):
            file_path = os.path.join(directory, filename)
            pdf_text = extract_text_from_pdf(file_path)
            data = parse_and_create_data(pdf_text, filename)
            csv_filename = os.path.splitext(filename)[0] + '.csv'
            csv_path = os.path.join(directory, csv_filename)
            with open(csv_path, 'w', newline='', encoding='utf-8') as csvfile:
                writer = csv.DictWriter(csvfile, fieldnames=header)
                writer.writeheader()
                writer.writerow(data)
            all_data.append(data)
    
    # Escribir todos los datos en un único archivo CSV
    with open(output_csv_file, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=header)
        writer.writeheader()
        for data in all_data:
            writer.writerow(data)

# Uso del código
directory = "./training/"
output_csv_file = "./output/facturas_output_nou.csv"
process_all_pdfs(directory, output_csv_file)
